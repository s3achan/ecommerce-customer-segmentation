# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv", encoding="ISO-8859-1")

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df_clean = df.copy() 
df_clean.columns = df_clean.columns.str.strip().str.lower()
df_clean['customerid'] = df_clean['customerid'].fillna("X")

# %%
df_clean.head(5)
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoicedate  unitprice customerid         country  totalprice  \
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom       20.34
#
#   year_month customertype
# 0    2010-12        Basic
# 1    2010-12        Basic
# 2    2010-12        Basic
# 3    2010-12        Basic
# 4    2010-12      General

# %%
df_clean['totalprice'] = df_clean['quantity'] * df_clean['unitprice']

# %%
df_clean['invoicedate'] = pd.to_datetime(df_clean['invoicedate'])

# %%
df_clean['year_month'] = df_clean['invoicedate'].dt.to_period('M')

# %%
monthly_spend = df_clean.groupby(['customerid','year_month'])['totalprice'].sum().reset_index()

# %%
avg_monthly = df_clean.groupby(['customerid','year_month'])['totalprice'].mean().reset_index()
avg_monthly.head(5)
# Out:
#   customerid year_month  totalprice
# 0    12346.0    2011-01    0.000000
# 1    12347.0    2010-12   22.960968
# 2    12347.0    2011-01   16.392759
# 3    12347.0    2011-04   26.510417
# 4    12347.0    2011-06   21.251111

# %%
X = avg_monthly.columns
y = avg_monthly.segment

# %%
avg_monthly.columns = ['customerid','avg_monthly','totalprice']

# %%
avg_monthly['segment'] = pd.qcut(
    avg_monthly['avg_monthly'],3,labels=['Basic','General','VIP'])

# %%
avg_monthly.columns
# Out:
# Index(['customerid', 'avg_monthly', 'totalprice', 'segment'], dtype='object')

# %%
X = avg_monthly[columns='customerid', 'avg_monthly', 'totalprice']
y = avg_monthly['segment']
# Out:
#   Cell In[67], line 1
#     X = avg_monthly[columns='customerid', 'avg_monthly', 'totalprice']
#                     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8268\2474803963.py in ?()
#       4 wcss = []
#       5
#       6 for i in range(1, 11):
#       7     kmeans = KMeans(n_clusters=i, random_state=42)
# ----> 8     kmeans.fit(X)
#       9     wcss.append(kmeans.inertia_)
#      10
#      11 plt.plot(range(1, 11), wcss)
#
# ~\anaconda3\envs\project\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\envs\project\lib\site-packages\sklearn\cluster\_kmeans.py in ?(self, X, y, sample_weight)
#    1450         -------
#    1451         self : object
#    1452             Fitted estimator.
#    1453         """
# -> 1454         X = validate_data(
#    1455             self,
#    1456             X,
#    1457             accept_sparse="csr",
#
# ~\anaconda3\envs\project\lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2950             out = y
#    2951         else:
#    2952             out = X, y
#    2953     elif not no_val_X and no_val_y:
# -> 2954         out = check_array(X, input_name="X", **check_params)
#    2955     elif no_val_X and not no_val_y:
#    2956         out = _check_y(y, **check_params)
#    2957     else:
#
# ~\anaconda3\envs\project\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1050                         )
#    1051                     array = xp.astype(array, dtype, copy=False)
#    1052                 else:
#    1053                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1054             except ComplexWarning as complex_warning:
#    1055                 raise ValueError(
#    1056                     "Complex data not supported\n{}\n".format(array)
#    1057                 ) from complex_warning
#
# ~\anaconda3\envs\project\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     753         # Use NumPy API to support order
#     754         if copy is True:
#     755             array = numpy.array(array, order=order, dtype=dtype)
#     756         else:
# --> 757             array = numpy.asarray(array, order=order, dtype=dtype)
#     758
#     759         # At this point array is a NumPy ndarray. We convert it to an array
#     760         # container that is consistent with the input's namespace.
#
# ~\anaconda3\envs\project\lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'C536379'
